# %%
# CNNbasic Assignment #1

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################
Conv_1 = (227-11 )/4+1
Conv_1
# Out:
# 55.0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Max_pool_1 = 0
Max_pool_1
# Out:
# 0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_2 = (27 + 2 * 2 - 5) / 1 + 1
Conv_2
# Out:
# 27.0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Max_pool_2 = 0
Max_pool_2
# Out:
# 0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_3 = (13 + 2 * 1 - 3) / 1 + 1
Conv_3
# Out:
# 13.0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_4 = (13 + 2 * 1 - 3) / 1 + 1
Conv_4
# Out:
# 13.0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_5 = (13 + 2 * 1 - 3) / 1 + 1
Conv_5
# Out:
# 13.0

# %%
Max_pool_3 = 0
Max_pool_3
# Out:
# 0

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC1 = 6 * 6 * 256
FC1
# Out:
# 9216

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC2 = 4096
FC2
# Out:
# 4096

# %%
######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC3 = 4096
FC3
# Out:
# 4096
